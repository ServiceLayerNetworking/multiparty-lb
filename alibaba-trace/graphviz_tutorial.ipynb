# %%
import graphviz as gv

# %%
# make a bipartite graph
g1 = gv.Graph(format='svg')
# g1.node('A')
# g1.node('B')
# g1.node('C')
# g1.node('D')
# g1.node('E')
# g1.node('F')
# g1.node('G')
# g1.node('H')


g1.edge('A', 'D')
g1.edge('A', 'D')
g1.edge('A', 'B')
g1.edge('B', 'H')

# %%
g1.render(directory='test_output', filename='bipartite_graph')
# Out:
# 'test_output/bipartite_graph.svg'
